# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52060/23CSBTB39-40/blob/main/AIML_ASSIGNMENT_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME:M.BHARATH
#
# ROLL NO:2303A52060
#
# ASSIGNMENT-6

# %% [markdown]
# 1.Implement the K Nearest Neighbor Classification using Classi-
# fied Manufacturing Dataset
#
# Part 1–Import the required Python, Pandas, Matplotlib, Seabor packages.
#
# 1. Load the classified dataset into a dataframe using pandas
# 2. Check the data types of each feature(column) in the dataset.
# 3. Generate a summary of the dataset for min, max, stddev,
# quartile vales for 25%,50%,75%,90%,
# 4. List the names of columns/features in the dataset
# 5. Scale the features using StandardScaler and transform the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
np.random.seed(0)
data = {
    'Feature1': np.random.rand(100) * 100,
    'Feature2': np.random.rand(100) * 50,
    'Feature3': np.random.rand(100) * 10,
    'target': np.random.choice(['Class1', 'Class2'], size=100)
}
df = pd.DataFrame(data)
print("First few rows of the dataset:")
print(df.head())
print("\nData types of each feature:")
print(df.dtypes)
print("\nSummary statistics:")
summary = df.describe(include='all', percentiles=[.25, .5, .75, .9])
print(summary)
print("\nColumn names:")
column_names = df.columns.tolist()
print(column_names)
df[['Feature1', 'Feature2', 'Feature3']].hist(bins=20, figsize=(10, 7))
plt.suptitle('Histograms of Original Features')
plt.show()
X = df.drop(columns=['target'])
y = df['target']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled_df.hist(bins=20, figsize=(10, 7))
plt.suptitle('Histograms of Scaled Features')
plt.show()
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.scatter(df['Feature1'], df['Feature2'], c=df['target'].apply(lambda x: 0 if x == 'Class1' else 1), cmap='viridis', alpha=0.7)
plt.title('Feature1 vs Feature2')
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.subplot(1, 3, 2)
plt.scatter(df['Feature1'], df['Feature3'], c=df['target'].apply(lambda x: 0 if x == 'Class1' else 1), cmap='viridis', alpha=0.7)
plt.title('Feature1 vs Feature3')
plt.xlabel('Feature1')
plt.ylabel('Feature3')
plt.subplot(1, 3, 3)
plt.scatter(df['Feature2'], df['Feature3'], c=df['target'].apply(lambda x: 0 if x == 'Class1' else 1), cmap='viridis', alpha=0.7)
plt.title('Feature2 vs Feature3')
plt.xlabel('Feature2')
plt.ylabel('Feature3')
plt.tight_layout()
plt.suptitle('Scatter Plots of Original Features')
plt.show()
# Out:
# First few rows of the dataset:
#     Feature1   Feature2  Feature3  target
# 0  54.881350  33.890827  3.117959  Class1
# 1  71.518937  13.500399  6.963435  Class1
# 2  60.276338  36.759701  3.777518  Class2
# 3  54.488318  48.109427  1.796037  Class2
# 4  42.365480  12.437657  0.246787  Class2
#
# Data types of each feature:
# Feature1    float64
# Feature2    float64
# Feature3    float64
# target       object
# dtype: object
#
# Summary statistics:
#           Feature1    Feature2    Feature3  target
# count   100.000000  100.000000  100.000000     100
# unique         NaN         NaN         NaN       2
# top            NaN         NaN         NaN  Class2
# freq           NaN         NaN         NaN      53
# mean     47.279384   26.404088    5.096320     NaN
# std      28.975402   13.905149    3.032006     NaN
# min       0.469548    0.585704    0.132369     NaN
# 25%      20.580316   14.779856    2.385470     NaN
# 50%      46.748099   28.762065    5.043552     NaN
# ...

# %% [markdown]
# Part 2–Model training and Fit the data to Model.
#
# 1. Split the data generated from list created as X, Y is distributed using train test split function as X train, Y train, X test, Y test
#
# 2. Apply the KNN Classifier model of sklearn.neighbors import KNeighborsClassifier package
#
# 3. Fit the data to the Classier Model using fit.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
np.random.seed(0)
data = {
    'Feature1': np.random.rand(100) * 100,
    'Feature2': np.random.rand(100) * 50,
    'Feature3': np.random.rand(100) * 10,
    'target': np.random.choice(['Class1', 'Class2'], size=100)
}
df = pd.DataFrame(data)
print("First few rows of the dataset:")
print(df.head())
print("\nData types of each feature:")
print(df.dtypes)
print("\nSummary statistics:")
summary = df.describe(include='all', percentiles=[.25, .5, .75, .9])
print(summary)
print("\nColumn names:")
column_names = df.columns.tolist()
print(column_names)
X = df.drop(columns=['target'])
y = df['target']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled_df.hist(bins=20, figsize=(10, 7))
plt.suptitle('Histograms of Scaled Features')
plt.show()
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.scatter(df['Feature1'], df['Feature2'], c=df['target'].apply(lambda x: 0 if x == 'Class1' else 1), cmap='viridis', alpha=0.7)
plt.title('Feature1 vs Feature2')
plt.xlabel('Feature1')
plt.ylabel('Feature2')

plt.subplot(1, 3, 2)
plt.scatter(df['Feature1'], df['Feature3'], c=df['target'].apply(lambda x: 0 if x == 'Class1' else 1), cmap='viridis', alpha=0.7)
plt.title('Feature1 vs Feature3')
plt.xlabel('Feature1')
plt.ylabel('Feature3')

plt.subplot(1, 3, 3)
plt.scatter(df['Feature2'], df['Feature3'], c=df['target'].apply(lambda x: 0 if x == 'Class1' else 1), cmap='viridis', alpha=0.7)
plt.title('Feature2 vs Feature3')
plt.xlabel('Feature2')
plt.ylabel('Feature3')
plt.tight_layout()
plt.suptitle('Scatter Plots of Original Features')
plt.show()
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.3, random_state=0)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("\nAccuracy of the KNN model:")
print(accuracy)
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# First few rows of the dataset:
#     Feature1   Feature2  Feature3  target
# 0  54.881350  33.890827  3.117959  Class1
# 1  71.518937  13.500399  6.963435  Class1
# 2  60.276338  36.759701  3.777518  Class2
# 3  54.488318  48.109427  1.796037  Class2
# 4  42.365480  12.437657  0.246787  Class2
#
# Data types of each feature:
# Feature1    float64
# Feature2    float64
# Feature3    float64
# target       object
# dtype: object
#
# Summary statistics:
#           Feature1    Feature2    Feature3  target
# count   100.000000  100.000000  100.000000     100
# unique         NaN         NaN         NaN       2
# top            NaN         NaN         NaN  Class2
# freq           NaN         NaN         NaN      53
# mean     47.279384   26.404088    5.096320     NaN
# std      28.975402   13.905149    3.032006     NaN
# min       0.469548    0.585704    0.132369     NaN
# 25%      20.580316   14.779856    2.385470     NaN
# 50%      46.748099   28.762065    5.043552     NaN
# ...

# %% [markdown]
# Part 3–Evaluate the Classification Quality.
#
# 1. Generate the confusion matrix to estimate the correction among features
#
# 2. Generate the classification report using classification report

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
np.random.seed(0)
data = {
    'Feature1': np.random.rand(100) * 100,
    'Feature2': np.random.rand(100) * 50,
    'Feature3': np.random.rand(100) * 10,
    'target': np.random.choice(['Class1', 'Class2'], size=100)
}
df = pd.DataFrame(data)
X = df.drop(columns=['target'])
y = df['target']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.3, random_state=0)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("\nAccuracy of the KNN model:")
print(accuracy)
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Class1', 'Class2'],
            yticklabels=['Class1', 'Class2'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
report_dict = classification_report(y_test, y_pred, output_dict=True)
report_df = pd.DataFrame(report_dict).transpose()
plt.figure(figsize=(10, 6))
sns.heatmap(report_df, annot=True, cmap='coolwarm', fmt='.2f',
            linewidths=.5, linecolor='black')
plt.title('Classification Report')
plt.show()
# Out:
# Accuracy of the KNN model:
# 0.36666666666666664
#
# Confusion Matrix:
# [[ 4 12]
#  [ 7  7]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Class1       0.36      0.25      0.30        16
#       Class2       0.37      0.50      0.42        14
#
#     accuracy                           0.37        30
#    macro avg       0.37      0.38      0.36        30
# weighted avg       0.37      0.37      0.36        30
